# %%
pip install google-api-python-client pandas
# Out:
# Requirement already satisfied: google-api-python-client in c:\users\mash\anaconda3\lib\site-packages (2.171.0)
# Requirement already satisfied: pandas in c:\users\mash\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\mash\anaconda3\lib\site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in c:\users\mash\anaconda3\lib\site-packages (from google-api-python-client) (2.40.2)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\mash\anaconda3\lib\site-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\mash\anaconda3\lib\site-packages (from google-api-python-client) (2.25.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\mash\anaconda3\lib\site-packages (from google-api-python-client) (4.2.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\mash\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mash\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mash\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mash\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\mash\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\mash\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (4.25.3)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\mash\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.26.1)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\mash\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\mash\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\mash\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\mash\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (4.9.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\mash\anaconda3\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\mash\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\mash\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mash\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mash\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mash\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mash\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# 🔑 Replace this list with your 6 API keys as needed
API_KEY = "AIzaSyBYHVKl2AvhyZMfd7QIwgjYEa0tg_QME9g"

# 🎯 Add your 10 confirmed channel handles
channel_handles = [
    "CA_RachanaRanade",
    "PranjalKamra",
    "AssetYogi",
    "Groww",
    "InvestYadnya",
    "AkshatShrivastava",
    "Elearnmarkets",
    "SOICFinance",
    "FinnovationZ_Convey",
    "PRSundar"
]

def get_channel_id(handle):
    url = f"https://www.googleapis.com/youtube/v3/search?part=snippet&type=channel&q={handle}&key={API_KEY}"
    response = requests.get(url).json()
    try:
        channel_id = response["items"][0]["snippet"]["channelId"]
        return channel_id
    except (KeyError, IndexError):
        return None

for handle in channel_handles:
    channel_id = get_channel_id(handle)
    print(f"Handle: @{handle} --> Channel ID: {channel_id}")
# Out:
# Handle: @CA_RachanaRanade --> Channel ID: UCe3qdG0A_gr-sEdat5y2twQ
# Handle: @PranjalKamra --> Channel ID: UCwAdQUuPT6laN-AQR17fe1g
# Handle: @AssetYogi --> Channel ID: UCsNxHPbaCWL1tKw2hxGQD6g
# Handle: @Groww --> Channel ID: UCw5TLrz3qADabwezTEcOmgQ
# Handle: @InvestYadnya --> Channel ID: UCPohbSYq4IXhv0yxiy-sT4g
# Handle: @AkshatShrivastava --> Channel ID: UCqW8jxh4tH1Z1sWPbkGWL4g
# Handle: @Elearnmarkets --> Channel ID: UCMec1m9iUC3agiEK-nsndSg
# Handle: @SOICFinance --> Channel ID: UCB7GnQlJPIL6rBBqEoX87vA
# Handle: @FinnovationZ_Convey --> Channel ID: UCICbCSJXQauULR7K8j6e0kg
# Handle: @PRSundar --> Channel ID: UCS2NdYUmv_PUyyKeDAo5zYA

# %%
pip install requests pandas vaderSentiment
# Out:
# Requirement already satisfied: requests in c:\users\mash\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: pandas in c:\users\mash\anaconda3\lib\site-packages (2.2.2)
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl.metadata (572 bytes)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mash\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mash\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mash\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mash\anaconda3\lib\site-packages (from requests) (2025.4.26)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\mash\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mash\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mash\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mash\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\mash\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy pandas matplotlib seaborn statsmodels scikit-learn requests beautifulsoup4
# Out:
# Requirement already satisfied: numpy in c:\users\mash\anaconda3\lib\site-packages (1.26.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pandas in c:\users\mash\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\mash\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: seaborn in c:\users\mash\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: statsmodels in c:\users\mash\anaconda3\lib\site-packages (0.14.2)
# Requirement already satisfied: scikit-learn in c:\users\mash\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: requests in c:\users\mash\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\mash\anaconda3\lib\site-packages (4.12.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mash\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mash\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mash\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mash\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mash\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mash\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\mash\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\mash\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\mash\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mash\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\mash\anaconda3\lib\site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\mash\anaconda3\lib\site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\mash\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\mash\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mash\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mash\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mash\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mash\anaconda3\lib\site-packages (from requests) (2025.4.26)
# Requirement already satisfied: soupsieve>1.2 in c:\users\mash\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: six in c:\users\mash\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)

# %%
import requests
import datetime
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import time
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import calendar # Added for month name in print statements

# === CONFIGURATION ===

# Your 6 YouTube Data API keys — one for each 6-month period from 2021 to 2023
API_KEYS = [
    "AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ86Ih1dcQ",  # Jan-Jun 2021
    "AIzaSyDgIdNGeCLHb_y9cBGozUw7i_BPpDrCHJg",  # Jul-Dec 2021
    "AIzaSyBWkx6Whvx0qz_0rTKJdghZcr35jqTvbes",  # Jan-Jun 2022
    "AIzaSyAMP7x0hGFOP0aeyoIy6VECqyfFm87tYh8",  # Jul-Dec 2022
    "AIzaSyCba-GzUM6UCc_WMeLspVyGibkAd434i08",  # Jan-Jun 2023
    "AIzaSyAkacu_GSHP7YwvfcELn9JZtIeE41C4s78",  # Jul-Dec 2023
]

# Your 10 channel IDs
CHANNEL_IDS = [
    "UCe3qdG0A_gr-sEdat5y2twQ",  # CA Rachana Ranade
    "UCwAdQUuPT6laN-AQR17fe1g",  # Pranjal Kamra
    "UCsNxHPbaCWL1tKw2hxGQD6g",  # Asset Yogi
    "UCw5TLrz3qADabwezTEcOmgQ",  # Groww
    "UCPohbSYq4IXhv0yxiy-sT4g",  # InvestYadnya
    "UCqW8jxh4tH1Z1sWPbkGWL4g",  # Akshat Shrivastava
    "UCMec1m9iUC3agiEK-nsndSg",  # Elearnmarkets
    "UCB7GnQlJPIL6rBBqEoX87vA",  # SOICFinance
    "UCICbCSJXQauULR7K8j6e0kg",  # FinnovationZ_Convey
    "UCS2NdYUmv_PUyyKeDAo5zYA",  # PRSundar
]

# Maximum number of videos per channel per month (to limit quota)
MAX_VIDEOS_PER_MONTH = 20

# Number of top comments to fetch per video
TOP_COMMENTS = 5

# Sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# === HELPER FUNCTIONS ===

def get_api_key_for_date(year, month):
    """Assigns the correct YouTube Data API key based on the year and month."""
    if year == 2021 and month <= 6:
        return API_KEYS[0]
    elif year == 2021 and month > 6:
        return API_KEYS[1]
    elif year == 2022 and month <= 6:
        return API_KEYS[2]
    elif year == 2022 and month > 6:
        return API_KEYS[3]
    elif year == 2023 and month <= 6:
        return API_KEYS[4]
    elif year == 2023 and month > 6:
        return API_KEYS[5]
    else:
        raise ValueError("Date outside range 2021-2023 for API key assignment.")

def get_date_range(year, month):
    """Calculates the ISO 8601 formatted start and end dates for a given month."""
    start_date = datetime.datetime(year, month, 1)
    if month == 12:
        end_date = datetime.datetime(year + 1, 1, 1)
    else:
        end_date = datetime.datetime(year, month + 1, 1)
    return start_date.isoformat("T") + "Z", end_date.isoformat("T") + "Z"

def requests_retry_session(
    retries=5, # Number of times to retry a failed request
    backoff_factor=0.5, # Factor for exponential backoff (0.5s, 1s, 2s, 4s, etc.)
    status_forcelist=(500, 502, 503, 504, 403, 429), # HTTP status codes that should trigger a retry (403 for Forbidden/Quota Exceeded, 429 for Too Many Requests)
    session=None, # Existing requests session to use
):
    """
    Creates a requests session with retry and exponential backoff logic.
    This helps in handling transient network errors and API rate limits.
    """
    session = session or requests.Session()
    # Define retry strategy
    retry = Retry(
        total=retries,
        read=retries, # Retries on read errors
        connect=retries, # Retries on connection errors
        backoff_factor=backoff_factor,
        status_forcelist=status_forcelist, # Status codes that trigger a retry
        allowed_methods=frozenset(['GET']), # Only retry GET requests
    )
    # Mount the adapter to both HTTP and HTTPS for all URLs
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    return session

def youtube_search_videos(channel_id, year, month, api_key, session):
    """
    Fetches video IDs and titles for a given channel within a specific month,
    using the provided requests session with retry logic.
    """
    start_iso, end_iso = get_date_range(year, month)
    videos = []
    page_token = None
    request_count = 0 # Track requests for this function to respect general API limits

    while True:
        url = (
            "https://www.googleapis.com/youtube/v3/search"
            f"?key={api_key}"
            "&part=snippet"
            f"&channelId={channel_id}"
            "&order=date"
            f"&publishedAfter={start_iso}"
            f"&publishedBefore={end_iso}"
            "&maxResults=50" # Max allowed per API call
            "&type=video"
        )
        if page_token:
            url += f"&pageToken={page_token}"

        print(f"    Fetching videos: {url[:80]}...") # Print part of the URL for debugging
        try:
            # Use the session for the request, with a timeout
            response = session.get(url, timeout=30) # Increased timeout to 30 seconds
            response.raise_for_status() # Raise an exception for 4xx or 5xx status codes
            data = response.json()
            request_count += 1

            for item in data.get("items", []):
                video_id = item["id"]["videoId"]
                title = item["snippet"]["title"]
                videos.append({"video_id": video_id, "title": title})

                if len(videos) >= MAX_VIDEOS_PER_MONTH:
                    break # Stop if we hit the limit for this month/channel

            if len(videos) >= MAX_VIDEOS_PER_MONTH:
                break # Stop if we hit the limit for this month/channel

            page_token = data.get("nextPageToken")
            if not page_token:
                break # No more pages

            # Brief pause between paginated requests for the same search query
            time.sleep(0.5)

        except requests.exceptions.RequestException as e:
            # Catch any requests-related error (ConnectionError, Timeout, HTTPError, etc.)
            print(f"    Error fetching videos for channel {channel_id} (month {month}, year {year}): {e}")
            if hasattr(e, 'response') and e.response is not None:
                print(f"      Status Code: {e.response.status_code}")
                print(f"      Response Text: {e.response.text}")
            break # Exit the loop if a persistent error occurs
        except Exception as e:
            print(f"    An unexpected error occurred in youtube_search_videos: {e}")
            break

    print(f"    Found {len(videos)} videos for channel {channel_id} in {calendar.month_name[month]} {year}.")
    return videos

def get_video_comments(video_id, api_key, session, max_comments=TOP_COMMENTS):
    """
    Fetches top comments for a given video ID, using the provided requests session with retry logic.
    """
    comments = []
    url = (
        "https://www.googleapis.com/youtube/v3/commentThreads"
        f"?key={api_key}"
        f"&part=snippet"
        f"&videoId={video_id}"
        f"&maxResults={max_comments}"
        "&order=relevance" # Most relevant comments first
        "&textFormat=plainText"
    )
    print(f"    Fetching comments for video {video_id}...")
    try:
        # Use the session for the request, with a timeout
        response = session.get(url, timeout=30) # Increased timeout to 30 seconds
        response.raise_for_status() # Raise an exception for 4xx or 5xx status codes
        data = response.json()

        for item in data.get("items", []):
            # Ensure topLevelComment and snippet exist before accessing
            if "topLevelComment" in item["snippet"] and "snippet" in item["snippet"]["topLevelComment"]:
                comment = item["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
                comments.append(comment)
            else:
                print(f"      Skipping comment due to missing snippet data for video {video_id}")

    except requests.exceptions.RequestException as e:
        print(f"    Error fetching comments for video {video_id}: {e}")
        if hasattr(e, 'response') and e.response is not None:
            print(f"      Status Code: {e.response.status_code}")
            print(f"      Response Text: {e.response.text}")
    except Exception as e:
        print(f"    An unexpected error occurred in get_video_comments: {e}")

    return comments

def sentiment_score(text):
    """Calculates the VADER sentiment compound score for a given text."""
    if not isinstance(text, str):
        return 0 # Return neutral sentiment for non-string input
    vs = analyzer.polarity_scores(text)
    return vs["compound"]  # range -1 to +1

# === MAIN PROCESS ===

def main():
    """
    Main function to orchestrate fetching YouTube data, calculating sentiment,
    and saving the results to a CSV file.
    """
    results = []

    # Create a single requests session with retry logic to be reused across all API calls
    # This is more efficient than creating a new session for each call
    api_session = requests_retry_session()

    for year in range(2021, 2024): # Loop through years 2021, 2022, 2023
        for month in range(1, 13): # Loop through months 1 to 12
            # Only process up to December 2023 as per API_KEYS definition
            if year == 2023 and month > 12:
                break
            print(f"\n--- Processing {calendar.month_name[month]} {year} ---")

            # Get the correct API key for the current period
            api_key = get_api_key_for_date(year, month)

            monthly_title_scores = []
            monthly_comment_scores = []

            for channel_id in CHANNEL_IDS:
                print(f"  Channel: {channel_id}")
                # Pass the shared session to the video search function
                videos = youtube_search_videos(channel_id, year, month, api_key, api_session)
                if not videos:
                    print(f"    No videos found for {channel_id} in {calendar.month_name[month]} {year}.")
                    continue

                for video in videos:
                    title = video["title"]
                    video_id = video["video_id"]

                    # Sentiment for title
                    title_sent = sentiment_score(title)
                    monthly_title_scores.append(title_sent)

                    # Sentiment for comments
                    # Pass the shared session to the comments function
                    comments = get_video_comments(video_id, api_key, api_session)
                    comment_sents = [sentiment_score(c) for c in comments] if comments else []
                    avg_comment_sent = sum(comment_sents) / len(comment_sents) if comment_sents else 0
                    monthly_comment_scores.append(avg_comment_sent)

                    # Weighted sentiment for this individual video (though not stored, useful for thought process)
                    # weighted_sent = 0.6 * title_sent + 0.4 * avg_comment_sent

                    # A brief pause after processing each video's comments
                    time.sleep(0.1)

                # A slightly longer pause after processing all videos for a channel
                time.sleep(0.5)

            # Aggregate monthly sentiment across all videos & channels for the current month
            avg_title_sent = sum(monthly_title_scores) / len(monthly_title_scores) if monthly_title_scores else None
            avg_comment_sent = sum(monthly_comment_scores) / len(monthly_comment_scores) if monthly_comment_scores else None

            # Final weighted sentiment for the month
            monthly_sentiment = None
            if avg_title_sent is not None and avg_comment_sent is not None:
                monthly_sentiment = 0.6 * avg_title_sent + 0.4 * avg_comment_sent
            elif avg_title_sent is not None:
                monthly_sentiment = avg_title_sent
            elif avg_comment_sent is not None:
                monthly_sentiment = avg_comment_sent

            results.append({
                "Year": year,
                "Month": month,
                "Average_Title_Sentiment": avg_title_sent,
                "Average_Comment_Sentiment": avg_comment_sent,
                "Weighted_Monthly_Sentiment": monthly_sentiment
            })
            # A longer pause between months to give the API a substantial break
            time.sleep(2) # 2 seconds between months

    # Save results to CSV
    df = pd.DataFrame(results)
    df.to_csv("youtube_monthly_sentiment.csv", index=False)
    print("\nSaved monthly sentiment data to 'youtube_monthly_sentiment.csv'")
    print("Script finished.")

if __name__ == "__main__":
    main()
# Out:
# --- Processing January 2021 ---
#   Channel: UCe3qdG0A_gr-sEdat5y2twQ
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 20 videos for channel UCe3qdG0A_gr-sEdat5y2twQ in January 2021.
#     Fetching comments for video SYNfUhfh_Dg...
#     Fetching comments for video U0a0JErlA5U...
#     Fetching comments for video ROJHbZlrOd8...
#     Fetching comments for video ZKXareXDebM...
#     Fetching comments for video wuwroU0h3QU...
#     Fetching comments for video almXhxmyTkM...
#     Fetching comments for video IxQlo9ewKGc...
#     Fetching comments for video AqOcQAL7cW0...
#     Fetching comments for video -hyed108bb0...
#     Fetching comments for video 03XxPwaufP4...
#     Fetching comments for video siVX6AXitVQ...
#     Fetching comments for video Hv2C-16eiuQ...
#     Fetching comments for video hPTrtp098vg...
#     Fetching comments for video hUvrysqCvP8...
#     Fetching comments for video 7pbgW3EDhcA...
#     Fetching comments for video o9SnN-o2MRA...
#     Fetching comments for video ys09m0WXgvI...
#     Fetching comments for video qimawEIGVCo...
#     Fetching comments for video IcgWTSaGXb8...
#     Fetching comments for video AzSUZAgGd48...
#   Channel: UCwAdQUuPT6laN-AQR17fe1g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 3 videos for channel UCwAdQUuPT6laN-AQR17fe1g in January 2021.
#     Fetching comments for video 5179LM9QDwI...
#     Fetching comments for video fx2GUJVxv6A...
#     Fetching comments for video cNmpGRwaaIk...
#   Channel: UCsNxHPbaCWL1tKw2hxGQD6g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 6 videos for channel UCsNxHPbaCWL1tKw2hxGQD6g in January 2021.
#     Fetching comments for video 46Mr0L_u-2U...
#     Fetching comments for video 4v3jEbAKxBg...
#     Fetching comments for video RnfZ26boM2M...
#     Fetching comments for video XaMBhE4ALus...
#     Fetching comments for video DlOwqy4d-zI...
#     Fetching comments for video LioenzfBkp0...
#   Channel: UCw5TLrz3qADabwezTEcOmgQ
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 20 videos for channel UCw5TLrz3qADabwezTEcOmgQ in January 2021.
#     Fetching comments for video NDKkYJZWe0c...
#     Fetching comments for video FjhbxYOT_l0...
#     Fetching comments for video Lind1TJLbIc...
#     Fetching comments for video lbfKDDg80kI...
#     Fetching comments for video x2hxpf8i3a0...
#     Fetching comments for video DcBC2XiOWjY...
#     Fetching comments for video JErIV8aR6us...
#     Fetching comments for video UG2tGDz4z4s...
#     Fetching comments for video IDDu3Dt7gzg...
#     Fetching comments for video SfTHqE-N9xw...
#     Fetching comments for video L0kv5jFU35g...
#     Fetching comments for video UfMJwzHj0g8...
#     Fetching comments for video CCJmdVtYgS4...
#     Fetching comments for video fHe7NBdUI4U...
#     Fetching comments for video 5Gu1frX6xLo...
#     Fetching comments for video oPeyQH7NPQY...
#     Fetching comments for video qrahYHDY6I4...
#     Fetching comments for video HsYS-JQRBbk...
#     Fetching comments for video o-tE9qN5Pek...
#     Fetching comments for video CWxk0AQlbCE...
#   Channel: UCPohbSYq4IXhv0yxiy-sT4g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 11 videos for channel UCPohbSYq4IXhv0yxiy-sT4g in January 2021.
#     Fetching comments for video gB8oNNJLoKc...
#     Fetching comments for video HVZCAmF1hEs...
#     Fetching comments for video ObO7uTnONBM...
#     Fetching comments for video oCqqEU3gHUw...
#     Fetching comments for video ydCHv2Zd6LQ...
#     Fetching comments for video VMl9GliQddE...
#     Fetching comments for video 0yahISTujo8...
#     Fetching comments for video rN-WZ3VRkNo...
#     Fetching comments for video GKUV_oSzw70...
#     Fetching comments for video P8zip_pL-lQ...
#     Fetching comments for video isUTSGGXAk0...
#   Channel: UCqW8jxh4tH1Z1sWPbkGWL4g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 0 videos for channel UCqW8jxh4tH1Z1sWPbkGWL4g in January 2021.
#     No videos found for UCqW8jxh4tH1Z1sWPbkGWL4g in January 2021.
#   Channel: UCMec1m9iUC3agiEK-nsndSg
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 13 videos for channel UCMec1m9iUC3agiEK-nsndSg in January 2021.
#     Fetching comments for video Y-EOtKUBq9s...
#     Fetching comments for video 4V_g6Fa8Xzg...
#     Fetching comments for video yQZkB50hxv8...
#     Fetching comments for video VzEU3vup3m8...
#     Fetching comments for video LcFWOIA5RDs...
#     Fetching comments for video D4qIlCYYAa0...
#     Fetching comments for video sIQgxjBG6kM...
#     Fetching comments for video KNKdFyS2LmA...
#     Fetching comments for video NB4F4awWgD4...
#     Fetching comments for video xfAj_QZ342w...
#     Fetching comments for video _DbQoFNLD4A...
#     Fetching comments for video EcpQY3pdFlA...
#     Fetching comments for video ph29IMvOlhc...
#   Channel: UCB7GnQlJPIL6rBBqEoX87vA
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 3 videos for channel UCB7GnQlJPIL6rBBqEoX87vA in January 2021.
#     Fetching comments for video BuTZmm_h6g4...
#     Fetching comments for video 2H6aDvmC4yY...
#     Fetching comments for video 0e_jy2dK1uI...
#   Channel: UCICbCSJXQauULR7K8j6e0kg
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 0 videos for channel UCICbCSJXQauULR7K8j6e0kg in January 2021.
#     No videos found for UCICbCSJXQauULR7K8j6e0kg in January 2021.
#   Channel: UCS2NdYUmv_PUyyKeDAo5zYA
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 20 videos for channel UCS2NdYUmv_PUyyKeDAo5zYA in January 2021.
#     Fetching comments for video _YtstIxwX1E...
#     Fetching comments for video pAZF9JAeUfo...
#     Fetching comments for video XYgmy6_Vyt4...
#     Fetching comments for video N0ksGVislFU...
#     Fetching comments for video sfAW0TNN8Kw...
#     Fetching comments for video U7W5ZCSyW2Y...
#     Fetching comments for video pWQCeCoHAno...
#     Fetching comments for video RC3yI4mEqLo...
#     Fetching comments for video jZtqKbjJzbk...
#     Fetching comments for video Eizc48meq6I...
#     Fetching comments for video 3aegGiP7S5s...
#     Fetching comments for video U2ll40g2XFo...
#     Fetching comments for video u9jcOvrN48Y...
#     Fetching comments for video VQowpF5gDGI...
#     Fetching comments for video ezf_iCUw9uc...
#     Fetching comments for video S2KMznaLuP0...
#     Fetching comments for video ZxHRtwoJJ2Y...
#     Fetching comments for video tSl_M1I7ZQQ...
#     Fetching comments for video zYp5F0xox94...
#     Fetching comments for video RfLHIKttH10...
#
# --- Processing February 2021 ---
#   Channel: UCe3qdG0A_gr-sEdat5y2twQ
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 12 videos for channel UCe3qdG0A_gr-sEdat5y2twQ in February 2021.
#     Fetching comments for video MeIaiaKX5D4...
#     Fetching comments for video rmI1PcGFCpI...
#     Fetching comments for video Lzw2dSYbN7Q...
#     Fetching comments for video sjSoKq6-cBU...
#     Fetching comments for video rxeUMcQ8zhs...
#     Fetching comments for video 6iddfDeeNzA...
#     Fetching comments for video kzur1dkNwOw...
#     Fetching comments for video wTUSu52fiC8...
#     Fetching comments for video tebjVMKfKXM...
#     Fetching comments for video DnP7QVd2oMs...
#     Fetching comments for video X-MN33IlGdE...
#     Fetching comments for video inidI3hA5Ig...
#   Channel: UCwAdQUuPT6laN-AQR17fe1g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 2 videos for channel UCwAdQUuPT6laN-AQR17fe1g in February 2021.
#     Fetching comments for video Wrv4pstlFDg...
#     Fetching comments for video Qioyo5JgC1U...
#   Channel: UCsNxHPbaCWL1tKw2hxGQD6g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 5 videos for channel UCsNxHPbaCWL1tKw2hxGQD6g in February 2021.
#     Fetching comments for video 49z9TMmwAnc...
#     Fetching comments for video CCklEi35Rbs...
#     Fetching comments for video cfy3hiOnHRA...
#     Fetching comments for video 998hYejik7g...
#     Fetching comments for video HmHwVxdmrsw...
#   Channel: UCw5TLrz3qADabwezTEcOmgQ
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 20 videos for channel UCw5TLrz3qADabwezTEcOmgQ in February 2021.
#     Fetching comments for video YNjT8w12wNs...
#     Fetching comments for video NP6vkFusm9I...
#     Fetching comments for video JhrmBg4vQHo...
#     Fetching comments for video jzEUzV_qTmw...
#     Fetching comments for video -lOp6i5Eepc...
#     Fetching comments for video bKoJxX7-JpM...
#     Fetching comments for video dMOdbblMm5Y...
#     Fetching comments for video HovEtpnn6KU...
#     Fetching comments for video ZXwdZ8imq6o...
#     Fetching comments for video TKoZOt77HT8...
#     Fetching comments for video C-NBCpyq-z4...
#     Fetching comments for video sr7rzY6hY_c...
#     Fetching comments for video 75W-a32l9hA...
#     Fetching comments for video 57HqvWMj1Og...
#     Fetching comments for video m1JpTctOFR8...
#     Fetching comments for video VUhha_qQVDY...
#     Fetching comments for video f57NGaw-BQI...
#     Fetching comments for video JGBX5SGIkx8...
#     Fetching comments for video gdW8qGjnw-g...
#     Fetching comments for video vKEZsqQz-6E...
#   Channel: UCPohbSYq4IXhv0yxiy-sT4g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 11 videos for channel UCPohbSYq4IXhv0yxiy-sT4g in February 2021.
#     Fetching comments for video py4YdF2MJiI...
#     Fetching comments for video -dlZ1bDYYlg...
#     Fetching comments for video HYdqi2j8vlg...
#     Fetching comments for video BaRiQ2wLG4k...
#     Fetching comments for video qA96HTHVLtY...
#     Fetching comments for video XGIONUs9Sfo...
#     Fetching comments for video 2Dcqo_mh780...
#     Fetching comments for video SLpZYGoF0xA...
#     Fetching comments for video 9JUpmrJLGXc...
#     Fetching comments for video zjrFmFryVnQ...
#     Fetching comments for video H4kvFQUzUV8...
#   Channel: UCqW8jxh4tH1Z1sWPbkGWL4g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 0 videos for channel UCqW8jxh4tH1Z1sWPbkGWL4g in February 2021.
#     No videos found for UCqW8jxh4tH1Z1sWPbkGWL4g in February 2021.
#   Channel: UCMec1m9iUC3agiEK-nsndSg
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 20 videos for channel UCMec1m9iUC3agiEK-nsndSg in February 2021.
#     Fetching comments for video gjGbGGjwiOg...
#     Fetching comments for video JK_WtS0kdTQ...
#     Fetching comments for video Bse2dDz_rMc...
#     Fetching comments for video rPU_i7cFY50...
#     Fetching comments for video Oajb5EJX3hs...
#     Fetching comments for video 5DG1pLSPyM4...
#     Fetching comments for video NoP4VbQz77Y...
#     Fetching comments for video x_LkOR4DZRI...
#     Fetching comments for video _gw9ktfO8IM...
#     Fetching comments for video s751SUY7_8w...
#     Fetching comments for video ihDDbWfRJLI...
#     Fetching comments for video Px0v9G766Kw...
#     Fetching comments for video ylnjtQrjilM...
#     Fetching comments for video Yy7QsHOjqLQ...
#     Fetching comments for video ylloxQZ9TUk...
#     Fetching comments for video aq1SXkae0UQ...
#     Fetching comments for video CdUQW-zDYeY...
#     Fetching comments for video lFo8gOOwjBg...
#     Fetching comments for video xeyUOZYUVcQ...
#     Fetching comments for video byv6Vv6z6ao...
#   Channel: UCB7GnQlJPIL6rBBqEoX87vA
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 1 videos for channel UCB7GnQlJPIL6rBBqEoX87vA in February 2021.
#     Fetching comments for video 4N6ZEOMecQg...
#   Channel: UCICbCSJXQauULR7K8j6e0kg
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 0 videos for channel UCICbCSJXQauULR7K8j6e0kg in February 2021.
#     No videos found for UCICbCSJXQauULR7K8j6e0kg in February 2021.
#   Channel: UCS2NdYUmv_PUyyKeDAo5zYA
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 20 videos for channel UCS2NdYUmv_PUyyKeDAo5zYA in February 2021.
#     Fetching comments for video MaB7fBIqOz0...
#     Fetching comments for video 79PbsPfGPE4...
#     Fetching comments for video JBV99xQRvxo...
#     Fetching comments for video TkUiZ6oYtd4...
#     Fetching comments for video Az-TnblxlSM...
#     Fetching comments for video xVoYcQfflYY...
#     Fetching comments for video aAeTl_nx-kw...
#     Fetching comments for video c2MWh6jRn3w...
#     Fetching comments for video FKUG_pqX53o...
#     Fetching comments for video eC_77zbwJYw...
#     Fetching comments for video 3UcGlgzbgyY...
#     Fetching comments for video 9Q7wPqfjPJk...
#     Fetching comments for video E-Jw8hgF8EI...
#     Fetching comments for video ddstqG7FJDs...
#     Fetching comments for video 6IyOFuEyk7Y...
#     Fetching comments for video L8hCnPmd6-Q...
#     Fetching comments for video JS9vwRMewYY...
#     Fetching comments for video HDA2BiL7si8...
#     Fetching comments for video mcGhyNmC0jQ...
#     Fetching comments for video BUAu9OjuKmQ...
#
# --- Processing March 2021 ---
#   Channel: UCe3qdG0A_gr-sEdat5y2twQ
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 20 videos for channel UCe3qdG0A_gr-sEdat5y2twQ in March 2021.
#     Fetching comments for video rNsomq1mNlY...
#     Fetching comments for video uPqNNshSA9I...
#     Fetching comments for video eGTj4qgm2As...
#     Fetching comments for video ih_dlF_VW6Y...
#     Fetching comments for video xifvYllUGso...
#     Fetching comments for video _BGJDPKxFXc...
#     Fetching comments for video iW3sl7DBBTk...
#     Fetching comments for video 3YnqJw7vg7M...
#     Fetching comments for video NXKRzvv3Z3c...
#     Fetching comments for video gk_pBpM14OM...
#     Fetching comments for video 5Hxr9v1enjg...
#     Fetching comments for video VsNxy1gOOZ8...
#     Fetching comments for video qvalLu7q84o...
#     Fetching comments for video C8bYrrwNIWw...
#     Fetching comments for video TCxajnln6jY...
#     Fetching comments for video 59z5yb5Dr4M...
#     Fetching comments for video ve5q3nlvO0o...
#     Fetching comments for video V1eyJTq1BvQ...
#     Fetching comments for video b2_5ScktQz0...
#     Fetching comments for video aC1IJHJJGlA...
#   Channel: UCwAdQUuPT6laN-AQR17fe1g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 3 videos for channel UCwAdQUuPT6laN-AQR17fe1g in March 2021.
#     Fetching comments for video bnQMSN55ehI...
#     Fetching comments for video obB7HLLPEXA...
#     Fetching comments for video HUoyhj9ATmw...
#   Channel: UCsNxHPbaCWL1tKw2hxGQD6g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 10 videos for channel UCsNxHPbaCWL1tKw2hxGQD6g in March 2021.
#     Fetching comments for video SH9f-SYYrDg...
#     Fetching comments for video F6bPLRHz2SU...
#     Fetching comments for video dh1UyjI7VgU...
#     Fetching comments for video PaVKKV8zHsY...
#     Fetching comments for video he_i7qQfXFs...
#     Fetching comments for video miiNnyx-QRs...
#     Fetching comments for video 6TkqyA9Ri3c...
#     Fetching comments for video MupVClb9yuA...
#     Fetching comments for video lJQh-krN8oc...
#     Fetching comments for video QBsZgWVmkA0...
#   Channel: UCw5TLrz3qADabwezTEcOmgQ
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 20 videos for channel UCw5TLrz3qADabwezTEcOmgQ in March 2021.
#     Fetching comments for video iOVhx16OINo...
#     Fetching comments for video bJ5MvEw_JNI...
#     Fetching comments for video ubs-0sr00M0...
#     Fetching comments for video Zyburmp6NtI...
#     Fetching comments for video iVg6m1h04GU...
#     Fetching comments for video uCEkpaCzJh4...
#     Fetching comments for video sBrgpNzhwaI...
#     Fetching comments for video t37qp0qkckA...
#     Fetching comments for video yDBrYe3kYKI...
#     Fetching comments for video ezAbgaeigkY...
#     Fetching comments for video S1Vv8DqkZ2Q...
#     Fetching comments for video XuVqMQvbEkA...
#     Fetching comments for video nwHLTqJv_Mo...
#     Fetching comments for video ZIqH__-D9AQ...
#     Fetching comments for video Q-wXAlLXz8Q...
#     Fetching comments for video E6ZrjAPMfWY...
#     Fetching comments for video dfx-OHIFly4...
#     Fetching comments for video tNd6g95JaFU...
#     Fetching comments for video erLliyMQgS8...
#     Fetching comments for video 70TK4IEqymM...
#   Channel: UCPohbSYq4IXhv0yxiy-sT4g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 18 videos for channel UCPohbSYq4IXhv0yxiy-sT4g in March 2021.
#     Fetching comments for video FlSeYGTEGdw...
#     Fetching comments for video 8-JDaOx3Ieo...
#     Fetching comments for video P7cWzozeD6o...
#     Fetching comments for video i9c0yVuxtc0...
#     Fetching comments for video 41gXPxg0CjU...
#     Fetching comments for video 1hscpvOXz-8...
#     Fetching comments for video EAh_3siUhWk...
#     Fetching comments for video Bu95UapoAI0...
#     Fetching comments for video Pk82KG9bJX0...
#     Fetching comments for video Y5Yo7teYaKk...
#     Fetching comments for video 83JgTaAkYRs...
#     Fetching comments for video 5dttZQpEICQ...
#     Fetching comments for video h12rdYuVgUM...
#     Fetching comments for video kOdQXBrfs_s...
#     Fetching comments for video lDUGn2dat0E...
#     Fetching comments for video U60d7822-Kc...
#     Fetching comments for video wtbGo789yTE...
#     Fetching comments for video QRyg0Fj0TDY...
#   Channel: UCqW8jxh4tH1Z1sWPbkGWL4g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 0 videos for channel UCqW8jxh4tH1Z1sWPbkGWL4g in March 2021.
#     No videos found for UCqW8jxh4tH1Z1sWPbkGWL4g in March 2021.
#   Channel: UCMec1m9iUC3agiEK-nsndSg
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 20 videos for channel UCMec1m9iUC3agiEK-nsndSg in March 2021.
#     Fetching comments for video uK2iTY32Ow4...
#     Fetching comments for video mBwL8jE41U0...
#     Fetching comments for video bPc_3vPj4JY...
#     Fetching comments for video 6_nhLxaH3nQ...
#     Fetching comments for video QfN4miFddVk...
#     Fetching comments for video WOW0LpRCeaU...
#     Fetching comments for video bj6hVKjweZ8...
#     Fetching comments for video RVCL3a_TQ-4...
#     Fetching comments for video 01TqTbxWOMw...
#     Fetching comments for video VKgU88hvVBI...
#     Fetching comments for video pYPs2KXiKe8...
#     Fetching comments for video GGpWTsCJk9Q...
#     Fetching comments for video 9CCHWSLP4ZA...
#     Fetching comments for video 5CAJu8zQ7a8...
#     Fetching comments for video l1C09K6rkQw...
#     Fetching comments for video 5JySdzv13Yo...
#     Fetching comments for video jstPESMyM2U...
#     Fetching comments for video 2lUqJDhoV5A...
#     Fetching comments for video kGxRQPheQ3s...
#     Fetching comments for video aZNncKS3JWY...
#   Channel: UCB7GnQlJPIL6rBBqEoX87vA
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 5 videos for channel UCB7GnQlJPIL6rBBqEoX87vA in March 2021.
#     Fetching comments for video dZ6larTHxdg...
#     Fetching comments for video 13BcR5cZfJY...
#     Fetching comments for video 5uI0Wo5H5yQ...
#     Fetching comments for video BUFVMyhVb00...
#     Fetching comments for video AdU-yq9QM4k...
#   Channel: UCICbCSJXQauULR7K8j6e0kg
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 1 videos for channel UCICbCSJXQauULR7K8j6e0kg in March 2021.
#     Fetching comments for video m88Qr5toxe4...
#   Channel: UCS2NdYUmv_PUyyKeDAo5zYA
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 20 videos for channel UCS2NdYUmv_PUyyKeDAo5zYA in March 2021.
#     Fetching comments for video ilnlqiNsX44...
#     Fetching comments for video 0zPEtLKUS50...
#     Fetching comments for video dCXQWNpWAS8...
#     Fetching comments for video G8Y0W0_z2GM...
#     Fetching comments for video 9q9Ing-7pgI...
#     Fetching comments for video 7HPUtYdsMEw...
#     Fetching comments for video yDAow09_QKY...
#     Fetching comments for video 47Mk8TkmTns...
#     Fetching comments for video wI3CfOtKjUA...
#     Fetching comments for video emBKuW3xaKE...
#     Fetching comments for video SgC76mMNHNU...
#     Fetching comments for video aHaeG6ISsfE...
#     Fetching comments for video 2PrzVg8u1CY...
#     Fetching comments for video jvuTYQVbqE8...
#     Fetching comments for video wGwuwdoy67Q...
#     Fetching comments for video YYwIijd_hQ4...
#     Fetching comments for video TTI34ErHY8g...
#     Fetching comments for video IXqfeJnMkqA...
#     Fetching comments for video zJYTptbcXSs...
#     Fetching comments for video f-KybstKAxw...
#
# --- Processing April 2021 ---
#   Channel: UCe3qdG0A_gr-sEdat5y2twQ
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 16 videos for channel UCe3qdG0A_gr-sEdat5y2twQ in April 2021.
#     Fetching comments for video XsdjWMyP-BQ...
#     Fetching comments for video 4srs4YjF8wE...
#     Fetching comments for video RdgS8XQFNic...
#     Fetching comments for video wODqBCZYCcw...
#     Fetching comments for video icyXl7B-s-4...
#     Fetching comments for video uTYAEHHAiqA...
#     Fetching comments for video hc_eEUh1TRA...
#     Fetching comments for video j1wuR87r0yU...
#     Fetching comments for video iWioahfpWYY...
#     Fetching comments for video Q-n5hO9f0HU...
#     Fetching comments for video b3X5pE-mnHg...
#     Fetching comments for video lqk2LppTl84...
#     Fetching comments for video 4BLSpNy3_go...
#     Fetching comments for video TLGalocqj00...
#     Fetching comments for video R5aDUli_sAc...
#     Fetching comments for video dScIcFAdBmU...
#   Channel: UCwAdQUuPT6laN-AQR17fe1g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 1 videos for channel UCwAdQUuPT6laN-AQR17fe1g in April 2021.
#     Fetching comments for video Y_-3_bG9G7E...
#   Channel: UCsNxHPbaCWL1tKw2hxGQD6g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 4 videos for channel UCsNxHPbaCWL1tKw2hxGQD6g in April 2021.
#     Fetching comments for video 5WE646HenMw...
#     Fetching comments for video juWL0ECpQP0...
#     Fetching comments for video VYo8DCKl5R0...
#     Fetching comments for video W7hU8bkXpLs...
#   Channel: UCw5TLrz3qADabwezTEcOmgQ
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 20 videos for channel UCw5TLrz3qADabwezTEcOmgQ in April 2021.
#     Fetching comments for video eDykCNILMJk...
#     Fetching comments for video uW9eQpfyEiw...
#     Fetching comments for video BPa6Z3uSAi0...
#     Fetching comments for video zLt_6VcVUBw...
#     Fetching comments for video tRJIWqAGafk...
#     Fetching comments for video bhgXpLQrdF8...
#     Fetching comments for video m8Od7X70-LE...
#     Fetching comments for video UF_uJ0b8Fm0...
#     Fetching comments for video s325HgGw3IQ...
#     Fetching comments for video 8isKZ8IWNNg...
#     Fetching comments for video cy9qTzhCPzA...
#     Fetching comments for video 1Ks6pfCDsEk...
#     Fetching comments for video JgToilQHk2g...
#     Fetching comments for video 7jYwJOIDJ8c...
#     Fetching comments for video PxlPxE17-uM...
#     Fetching comments for video 0B5R7Qhl7Fg...
#     Fetching comments for video hoAJw3c6fsQ...
#     Fetching comments for video qvfphA8eHF8...
#     Fetching comments for video B8AFd5y5J14...
#     Fetching comments for video QGq18x5-LmE...
#   Channel: UCPohbSYq4IXhv0yxiy-sT4g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 18 videos for channel UCPohbSYq4IXhv0yxiy-sT4g in April 2021.
#     Fetching comments for video 495B2AERCKU...
#     Fetching comments for video Rxrd6_OIB0A...
#     Fetching comments for video yRisj7II2ps...
#     Fetching comments for video b_c36kjw0Pc...
#     Fetching comments for video mKnXH6rSh5g...
#     Fetching comments for video SA3oIUJerLQ...
#     Fetching comments for video 7iG3I9TPYF8...
#     Fetching comments for video WsPrQ0Y0Dm8...
#     Fetching comments for video wBF6GKebFTA...
#     Fetching comments for video 8xRg-_QO09Q...
#     Fetching comments for video c9mZAmCXzf4...
#     Fetching comments for video 2-W-6wez7R0...
#     Fetching comments for video wACJNZEcJko...
#     Fetching comments for video y2xHvUL3jH8...
#     Fetching comments for video rns9p74fVG4...
#     Fetching comments for video htYZSnjNw9c...
#     Fetching comments for video NNzziM4NhxA...
#     Fetching comments for video e5FNqOI4Gds...
#   Channel: UCqW8jxh4tH1Z1sWPbkGWL4g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 0 videos for channel UCqW8jxh4tH1Z1sWPbkGWL4g in April 2021.
#     No videos found for UCqW8jxh4tH1Z1sWPbkGWL4g in April 2021.
#   Channel: UCMec1m9iUC3agiEK-nsndSg
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 12 videos for channel UCMec1m9iUC3agiEK-nsndSg in April 2021.
#     Fetching comments for video qeHPXsgElSU...
#     Fetching comments for video isaj8zyfBSQ...
#     Fetching comments for video fi36CUDk5NE...
#     Fetching comments for video gjfg36v2oS4...
#     Fetching comments for video a2iKKnh9Flw...
#     Fetching comments for video dol8dpM3Jfw...
#     Fetching comments for video DV-c9Cm4Yik...
#     Fetching comments for video XlOcbL0B1uM...
#     Fetching comments for video Vbwm1pi_ErA...
#     Fetching comments for video 20Fuvxjm5JY...
#     Fetching comments for video SCeuRWWdc_A...
#     Fetching comments for video BrogppQdtWM...
#   Channel: UCB7GnQlJPIL6rBBqEoX87vA
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 4 videos for channel UCB7GnQlJPIL6rBBqEoX87vA in April 2021.
#     Fetching comments for video 2PGLUK6l7dg...
#     Fetching comments for video wcwOSku_2D8...
#     Fetching comments for video EbT4XZ40LwU...
#     Fetching comments for video AaD2mFXGq-M...
#   Channel: UCICbCSJXQauULR7K8j6e0kg
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 1 videos for channel UCICbCSJXQauULR7K8j6e0kg in April 2021.
#     Fetching comments for video amopgfyDjAc...
#   Channel: UCS2NdYUmv_PUyyKeDAo5zYA
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 20 videos for channel UCS2NdYUmv_PUyyKeDAo5zYA in April 2021.
#     Fetching comments for video _zIEfzXK5yg...
#     Fetching comments for video 1fYo3MF6Bnw...
#     Fetching comments for video wPfaxLpi1oQ...
#     Fetching comments for video qd9iY2dm-Ng...
#     Fetching comments for video kEY_8dbYQ28...
#     Fetching comments for video __Csp2gfgP8...
#     Fetching comments for video I3X_Sj_wkJ8...
#     Fetching comments for video rUOOOGeKxHA...
#     Fetching comments for video HbMgcDuWauk...
#     Fetching comments for video JTRU-3EH3Go...
#     Fetching comments for video 7iBNzEpR9eU...
#     Fetching comments for video d6wrlZI4Nk8...
#     Fetching comments for video gO0Lu3GKkEM...
#     Fetching comments for video dZH5Y9kRueY...
#     Fetching comments for video u07yzEZ3zrY...
#     Fetching comments for video DmcUVgFMMmA...
#     Fetching comments for video wRz56S2QUvY...
#     Fetching comments for video NUcU-yiKBSw...
#     Fetching comments for video 3yZG18ohta0...
#     Fetching comments for video tl71ive1Zss...
#
# --- Processing May 2021 ---
#   Channel: UCe3qdG0A_gr-sEdat5y2twQ
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 13 videos for channel UCe3qdG0A_gr-sEdat5y2twQ in May 2021.
#     Fetching comments for video rdX_fkFFBok...
#     Fetching comments for video Gcd99gDe4gk...
#     Fetching comments for video EKVW0zWGMdk...
#     Fetching comments for video jLdwFGtaMcA...
#     Fetching comments for video A8ga4Ja9OME...
#     Fetching comments for video WxoNEtQSxd4...
#     Fetching comments for video RVc58Ipbj7M...
#     Fetching comments for video JtKQHZvMp5Q...
#     Fetching comments for video jH-zRnaBLaY...
#     Fetching comments for video NRtFvuzPWyQ...
#     Fetching comments for video W4Vt8iz6EZU...
#     Fetching comments for video Pvd1Y0OR2Nk...
#     Fetching comments for video T_NIXo3q09c...
#   Channel: UCwAdQUuPT6laN-AQR17fe1g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 4 videos for channel UCwAdQUuPT6laN-AQR17fe1g in May 2021.
#     Fetching comments for video wMe_BKHXEEs...
#     Fetching comments for video y-j47ieLzr8...
#     Fetching comments for video l60ZZYref_w...
#     Fetching comments for video jCIo4_RoxPE...
#   Channel: UCsNxHPbaCWL1tKw2hxGQD6g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 5 videos for channel UCsNxHPbaCWL1tKw2hxGQD6g in May 2021.
#     Fetching comments for video gEMZKXwNNRo...
#     Fetching comments for video 6ymzyay0NBs...
#     Fetching comments for video NhJOQL4c7NQ...
#     Fetching comments for video _1EsjQFDRW4...
#     Fetching comments for video gaen-QfWtMY...
#   Channel: UCw5TLrz3qADabwezTEcOmgQ
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 20 videos for channel UCw5TLrz3qADabwezTEcOmgQ in May 2021.
#     Fetching comments for video _kn7XfKb5JI...
#     Fetching comments for video lv0X-CPrTRs...
#     Fetching comments for video RoN9Tvr1oRg...
#     Fetching comments for video tl7YIU9FkaM...
#     Fetching comments for video 1pj6JPJaWcc...
#     Fetching comments for video F_LOItPk3Z4...
#     Fetching comments for video RWwFbWZesJc...
#     Fetching comments for video chEORSU0agU...
#     Fetching comments for video oUh3fBSjRAU...
#     Fetching comments for video bzVqISL790E...
#     Fetching comments for video s5X29peDDhk...
#     Fetching comments for video 04dWQPz5WYY...
#     Fetching comments for video CgenNmTlJRg...
#     Fetching comments for video 3CaKqz-5ZVs...
#     Fetching comments for video kwxgt9o9DZ4...
#     Fetching comments for video N3AAtFIR9Cw...
#     Fetching comments for video ePGHnWrd6sw...
#     Fetching comments for video HD0w-IJwOgI...
#     Fetching comments for video eRi6W_udDwY...
#     Fetching comments for video 1quE_OQECco...
#   Channel: UCPohbSYq4IXhv0yxiy-sT4g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 14 videos for channel UCPohbSYq4IXhv0yxiy-sT4g in May 2021.
#     Fetching comments for video h69o_Zo0ngs...
#     Fetching comments for video U5NKU_aT3zU...
#     Fetching comments for video T0F5tnCiByU...
#     Fetching comments for video UIEJnsZid2c...
#     Fetching comments for video xESYRdsv_74...
#     Fetching comments for video vfdkZeriCr0...
#     Fetching comments for video U3cE6p1wTz4...
#     Fetching comments for video KCQOtkfzAvc...
#     Fetching comments for video 7C5EDH2Gryg...
#     Fetching comments for video D87ldeRaRlw...
#     Fetching comments for video DSbEref3zn4...
#     Fetching comments for video A4VaFFOnlZU...
#     Fetching comments for video DJm_3EKyaVo...
#     Fetching comments for video a0poxqsdavk...
#   Channel: UCqW8jxh4tH1Z1sWPbkGWL4g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 3 videos for channel UCqW8jxh4tH1Z1sWPbkGWL4g in May 2021.
#     Fetching comments for video BH96YTu88p8...
#     Fetching comments for video Vh0f3K8Jp1I...
#     Fetching comments for video niEK_1Xwwws...
#   Channel: UCMec1m9iUC3agiEK-nsndSg
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 8 videos for channel UCMec1m9iUC3agiEK-nsndSg in May 2021.
#     Fetching comments for video zoe-7_Zs980...
#     Fetching comments for video 3qRu8_e50rI...
#     Fetching comments for video s32q8V9RKms...
#     Fetching comments for video twsigS8CLEQ...
#     Fetching comments for video LlQUdobJWFQ...
#     Fetching comments for video CZh0ixEgibw...
#     Fetching comments for video hpYmVBNs9Vw...
#     Fetching comments for video sdWFwUX8--o...
#   Channel: UCB7GnQlJPIL6rBBqEoX87vA
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 4 videos for channel UCB7GnQlJPIL6rBBqEoX87vA in May 2021.
#     Fetching comments for video -6FLHjxzi8o...
#     Fetching comments for video -L7WGwYGTUc...
#     Fetching comments for video giiBC7vxKc0...
#     Fetching comments for video H2f2ZxEtu2E...
#   Channel: UCICbCSJXQauULR7K8j6e0kg
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 0 videos for channel UCICbCSJXQauULR7K8j6e0kg in May 2021.
#     No videos found for UCICbCSJXQauULR7K8j6e0kg in May 2021.
#   Channel: UCS2NdYUmv_PUyyKeDAo5zYA
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 20 videos for channel UCS2NdYUmv_PUyyKeDAo5zYA in May 2021.
#     Fetching comments for video _JzqUUH5JBk...
#     Fetching comments for video M5ocSkZjCBI...
#     Fetching comments for video i1J9oiyo3T8...
#     Fetching comments for video nf7InaBK9q0...
#     Fetching comments for video 3nospatCNeQ...
#     Fetching comments for video -N3CT2Ox2S4...
#     Fetching comments for video _T4Azl8NLIk...
#     Fetching comments for video NWYMd-oCFW0...
#     Fetching comments for video qZlSs2zW6l4...
#     Fetching comments for video vM0CZ3X9OB0...
#     Fetching comments for video 91_tsUti6EA...
#     Fetching comments for video 2ySSMgfIyKY...
#     Fetching comments for video 8IKSgV94Ttk...
#     Fetching comments for video zmdGeNViTTU...
#     Fetching comments for video Jtq-smUAYYY...
#     Fetching comments for video 9OIX5VGt9xQ...
#     Fetching comments for video eyfMNYi0KZI...
#     Fetching comments for video IuJh9g6n604...
#     Fetching comments for video Zb93EjRurCk...
#     Fetching comments for video CoWki-GdFbs...
#
# --- Processing June 2021 ---
#   Channel: UCe3qdG0A_gr-sEdat5y2twQ
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 15 videos for channel UCe3qdG0A_gr-sEdat5y2twQ in June 2021.
#     Fetching comments for video vDf2pLn4Q48...
#     Fetching comments for video KlTRpJS9x8Y...
#     Fetching comments for video H4nDvH5Ci9w...
#     Fetching comments for video POfmy7ZQAb4...
#     Fetching comments for video yC_TVRWlPeA...
#     Fetching comments for video giv2f1FebFA...
#     Fetching comments for video nxMiEWSTo-0...
#     Fetching comments for video keWYSdRg78g...
#     Fetching comments for video BGwbSvQ1hNU...
#     Fetching comments for video Aez-cZNS0qU...
#     Fetching comments for video uyBkQrdKsBw...
#     Fetching comments for video gpYjnR5ZMrc...
#     Fetching comments for video tHxwyWnNu0c...
#     Fetching comments for video WZOslCXltgE...
#     Fetching comments for video yO1iIHJo-28...
#   Channel: UCwAdQUuPT6laN-AQR17fe1g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 11 videos for channel UCwAdQUuPT6laN-AQR17fe1g in June 2021.
#     Fetching comments for video eH5yjjrNk7s...
#     Fetching comments for video t5cQhUnUKbI...
#     Fetching comments for video k9VH6mjIfO4...
#     Fetching comments for video ceWrSVLpJDg...
#     Fetching comments for video nGszy-K4jLE...
#     Fetching comments for video 7yFkZM2w54Q...
#     Fetching comments for video gBpQwIwBz2U...
#     Fetching comments for video 9ZAy60_A4as...
#     Fetching comments for video e043Xu3Eyqs...
#     Fetching comments for video 0NmSpOcdsj0...
#     Fetching comments for video LX1UxFHRRk0...
#   Channel: UCsNxHPbaCWL1tKw2hxGQD6g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 4 videos for channel UCsNxHPbaCWL1tKw2hxGQD6g in June 2021.
#     Fetching comments for video 8V7byeoZsgY...
#     Fetching comments for video yT71rbPHyN0...
#     Fetching comments for video nTuwuUzSTao...
#     Fetching comments for video dJSYwOw1zv0...
#   Channel: UCw5TLrz3qADabwezTEcOmgQ
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 20 videos for channel UCw5TLrz3qADabwezTEcOmgQ in June 2021.
#     Fetching comments for video L6KXBoSUD6o...
#     Fetching comments for video L-CJV6Nf1Jk...
#     Fetching comments for video pf3fmwbh8B0...
#     Fetching comments for video QW7H-inE35s...
#     Fetching comments for video NUFeUuKZkD0...
#     Fetching comments for video KlTEK030_oM...
#     Fetching comments for video Spuff26sCEQ...
#     Fetching comments for video V94JCQs_vqw...
#     Fetching comments for video lo0cMbbZvew...
#     Fetching comments for video c5PylY-PBqQ...
#     Fetching comments for video XXnD7fsvtlU...
#     Fetching comments for video FkNQNfG-ZhE...
#     Fetching comments for video BLq_6tPT2Zk...
#     Fetching comments for video dGqq57xV3aI...
#     Fetching comments for video vuoKSes7ZUo...
#     Fetching comments for video doNCUnzmZvE...
#     Fetching comments for video 1z-kz-vaY3c...
#     Fetching comments for video N5YgmNKUjEw...
#     Fetching comments for video 0G0gIv8lS4o...
#     Fetching comments for video MFC8iGopjmA...
#   Channel: UCPohbSYq4IXhv0yxiy-sT4g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 13 videos for channel UCPohbSYq4IXhv0yxiy-sT4g in June 2021.
#     Fetching comments for video pVUbrjjAj4Y...
#     Fetching comments for video hJdhp7pN3R4...
#     Fetching comments for video E7PcwlGu4Cw...
#     Fetching comments for video 7qhby_1ZQT8...
#     Fetching comments for video oJ6UcqPDoqY...
#     Fetching comments for video V77V8q_dTco...
#     Fetching comments for video zMuR39A1wmo...
#     Fetching comments for video DpD_23GYdAQ...
#     Fetching comments for video -iWwNRAAPic...
#     Fetching comments for video 2DRrv-2niKs...
#     Fetching comments for video 1HmOM1DF0r0...
#     Fetching comments for video HEbE5PLnpv0...
#     Fetching comments for video Qe447V8PfBY...
#   Channel: UCqW8jxh4tH1Z1sWPbkGWL4g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 20 videos for channel UCqW8jxh4tH1Z1sWPbkGWL4g in June 2021.
#     Fetching comments for video EYM2UENSObk...
#     Fetching comments for video 1EYKX-11aeo...
#     Fetching comments for video -wQDfiiDBaU...
#     Fetching comments for video XXPo8SvZPpc...
#     Fetching comments for video cGNTVozi6Ns...
#     Fetching comments for video mHh6gnYvEFQ...
#     Fetching comments for video R29lvWs1yBE...
#     Fetching comments for video BUJv7ehejpU...
#     Fetching comments for video krBXdItE5m0...
#     Fetching comments for video RpNkyTtmC6o...
#     Fetching comments for video _DYuHz9VBLo...
#     Fetching comments for video hLqGReZSr5c...
#     Fetching comments for video -07FjvLc_fg...
#     Fetching comments for video rT6nZdCZFN8...
#     Fetching comments for video gK29O6rf_f4...
#     Fetching comments for video IvWI14YKw9A...
#     Fetching comments for video TXJ-8m9NxJA...
#     Fetching comments for video HSUsSBk7Wqg...
#     Fetching comments for video Q1ZJ3NaVYNA...
#     Fetching comments for video GPdaC1957oA...
#   Channel: UCMec1m9iUC3agiEK-nsndSg
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 20 videos for channel UCMec1m9iUC3agiEK-nsndSg in June 2021.
#     Fetching comments for video F6VeyCfUw_4...
#     Fetching comments for video 8jskIb7Kc-Q...
#     Fetching comments for video FdW2UkjOmV4...
#     Fetching comments for video GZTjAl3gIik...
#     Fetching comments for video JTcsmysnGRM...
#     Fetching comments for video HWTlUiOZ9Nk...
#     Fetching comments for video gz4jWMYPxoM...
#     Fetching comments for video wacDOB_g1zc...
#     Fetching comments for video dwuTRDcsgDg...
#     Fetching comments for video IjBE5FtEI1Y...
#     Fetching comments for video BQaBlu0XhpU...
#     Fetching comments for video -7or1EunZuM...
#     Fetching comments for video c8pVBpThOPs...
#     Fetching comments for video z2vRmyazFlw...
#     Fetching comments for video Dx8ze-tjHtk...
#     Fetching comments for video XPuoJD83Eqs...
#     Fetching comments for video xE6S6MuGYco...
#     Fetching comments for video Sr2P0n4syO8...
#     Fetching comments for video G6w0zxu3RfM...
#     Error fetching comments for video G6w0zxu3RfM: HTTPSConnectionPool(host='www.googleapis.com', port=443): Max retries exceeded with url: /youtube/v3/commentThreads?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ86Ih1dcQ&part=snippet&videoId=G6w0zxu3RfM&maxResults=5&order=relevance&textFormat=plainText (Caused by ResponseError('too many 403 error responses'))
#     Fetching comments for video 75A2Taf_j2k...
#   Channel: UCB7GnQlJPIL6rBBqEoX87vA
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 6 videos for channel UCB7GnQlJPIL6rBBqEoX87vA in June 2021.
#     Fetching comments for video ifPUFHkS_QA...
#     Fetching comments for video _P2VgNTsQGY...
#     Fetching comments for video LqwkFGTiDhA...
#     Fetching comments for video z4uuvjysFn0...
#     Fetching comments for video CTzPO9INKG0...
#     Fetching comments for video z8BJvqCS6fs...
#   Channel: UCICbCSJXQauULR7K8j6e0kg
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 0 videos for channel UCICbCSJXQauULR7K8j6e0kg in June 2021.
#     No videos found for UCICbCSJXQauULR7K8j6e0kg in June 2021.
#   Channel: UCS2NdYUmv_PUyyKeDAo5zYA
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDxu_G2sSqJjXO0RCcvybBKHhZ...
#     Found 20 videos for channel UCS2NdYUmv_PUyyKeDAo5zYA in June 2021.
#     Fetching comments for video Ge21VtOzS7k...
#     Fetching comments for video IhYZ0b5zhzQ...
#     Fetching comments for video fD8CxMVcg3Q...
#     Fetching comments for video crhHt1vzdaI...
#     Fetching comments for video xiN1DHFq4Eg...
#     Fetching comments for video owKGVlb9n_I...
#     Fetching comments for video Qq-tre3wUUA...
#     Fetching comments for video Q-8uc-A6tBk...
#     Fetching comments for video ReodIpHoKbY...
#     Fetching comments for video qIxncLcKjqY...
#     Fetching comments for video IPZF4tBvMY8...
#     Fetching comments for video p4TvVCw2ClY...
#     Fetching comments for video WL_5iqdhKqo...
#     Fetching comments for video sHwADM_QHLk...
#     Fetching comments for video PZ9bz2yq5Gg...
#     Fetching comments for video ubFREOZvZG0...
#     Fetching comments for video SXpXDW15YKM...
#     Fetching comments for video b9CLz-InbAo...
#     Fetching comments for video I5gAiBOYtfM...
#     Fetching comments for video b7WXgWo9ndg...
#
# --- Processing July 2021 ---
#   Channel: UCe3qdG0A_gr-sEdat5y2twQ
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDgIdNGeCLHb_y9cBGozUw7i_B...
#     Found 13 videos for channel UCe3qdG0A_gr-sEdat5y2twQ in July 2021.
#     Fetching comments for video gh5b-MzDl6I...
#     Fetching comments for video y_RAuDKPrm4...
#     Fetching comments for video BHvXwKxKkFw...
#     Fetching comments for video tbc8zLcbW5Q...
#     Fetching comments for video x5qvK6SJoF4...
#     Fetching comments for video MNfRzLjJJeg...
#     Fetching comments for video 1wDAhDZUP3k...
#     Fetching comments for video g5cIOEX0HFI...
#     Fetching comments for video gSVLeSDl2zQ...
#     Fetching comments for video sbaMMXSAnT0...
#     Fetching comments for video 3E2InZbReQE...
#     Fetching comments for video 16iIbJ8rH4M...
#     Fetching comments for video dgYKgzvcr2U...
#   Channel: UCwAdQUuPT6laN-AQR17fe1g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDgIdNGeCLHb_y9cBGozUw7i_B...
#     Found 5 videos for channel UCwAdQUuPT6laN-AQR17fe1g in July 2021.
#     Fetching comments for video xU_FZCrGlwA...
#     Fetching comments for video qwicnPIIO2A...
#     Fetching comments for video YCgvL0Yy1XI...
#     Fetching comments for video yeCo_ockidU...
#     Fetching comments for video UBHN3c9NDaU...
#   Channel: UCsNxHPbaCWL1tKw2hxGQD6g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDgIdNGeCLHb_y9cBGozUw7i_B...
#     Found 5 videos for channel UCsNxHPbaCWL1tKw2hxGQD6g in July 2021.
#     Fetching comments for video uUtCRwaEMwY...
#     Fetching comments for video PnnHa3u_w2M...
#     Fetching comments for video jDUXI-RaiDs...
#     Fetching comments for video jUZAh4aHfEc...
#     Fetching comments for video wtX4ZsHFKxc...
#   Channel: UCw5TLrz3qADabwezTEcOmgQ
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDgIdNGeCLHb_y9cBGozUw7i_B...
#     Found 20 videos for channel UCw5TLrz3qADabwezTEcOmgQ in July 2021.
#     Fetching comments for video IGm1QR_PNw4...
#     Fetching comments for video 2BoR_xiSQX8...
#     Fetching comments for video ohKdxHd6UVc...
#     Fetching comments for video 2vZH1TWni3s...
#     Fetching comments for video D_DqaHKJ4ZQ...
#     Fetching comments for video f7XEz8vXbzE...
#     Fetching comments for video YBDPmzXZVHA...
#     Fetching comments for video EXnuxHsvrJo...
#     Fetching comments for video _PkEH9cPrUU...
#     Fetching comments for video _xCMWf5sByY...
#     Fetching comments for video hCZYtWlDySA...
#     Fetching comments for video uCyAaLxDhgc...
#     Fetching comments for video 69vjHb2tnNA...
#     Fetching comments for video h8YfA_Prvic...
#     Fetching comments for video lbArzHApkWw...
#     Fetching comments for video GOQgqW4HVNQ...
#     Fetching comments for video HpFiq1d9BFY...
#     Fetching comments for video PTkifFxyua8...
#     Fetching comments for video MjY5VLzAp6Y...
#     Fetching comments for video Ek0HNvjMJjs...
#   Channel: UCPohbSYq4IXhv0yxiy-sT4g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDgIdNGeCLHb_y9cBGozUw7i_B...
#     Found 11 videos for channel UCPohbSYq4IXhv0yxiy-sT4g in July 2021.
#     Fetching comments for video PWcJZzSBkcg...
#     Fetching comments for video _uhU1-JDDiE...
#     Fetching comments for video cmYdtFC1SJQ...
#     Fetching comments for video o8sThBXRINk...
#     Fetching comments for video k86ud5r_Llo...
#     Fetching comments for video bowrRiaV-Qw...
#     Fetching comments for video fXszXG1oOf8...
#     Fetching comments for video 8o7m_-zyz_g...
#     Fetching comments for video 2xzkhZdvDCk...
#     Fetching comments for video Cy0sC-2xEbI...
#     Fetching comments for video AhG2BnJjPw4...
#   Channel: UCqW8jxh4tH1Z1sWPbkGWL4g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDgIdNGeCLHb_y9cBGozUw7i_B...
#     Found 20 videos for channel UCqW8jxh4tH1Z1sWPbkGWL4g in July 2021.
#     Fetching comments for video 7Xc9alkDMH8...
#     Fetching comments for video -xOZP3Ut8J0...
#     Fetching comments for video DvjCPu0odG4...
#     Fetching comments for video 1ktVglH2xk4...
#     Fetching comments for video g7jO8Qdn43Y...
#     Fetching comments for video zQZVISQWvLU...
#     Fetching comments for video 0Ef0Iy9Vf_A...
#     Fetching comments for video ie-n7tIX0EU...
#     Fetching comments for video 2LuanPuxBnE...
#     Fetching comments for video ZwPjQYCKzgc...
#     Fetching comments for video IZ12jzjts-Q...
#     Fetching comments for video X9Bk2AlQrDA...
#     Fetching comments for video iSZ0iULWymI...
#     Fetching comments for video Pylw3tqzv1U...
#     Fetching comments for video 3C6Y8dGF3Sc...
#     Fetching comments for video z7flclYFFsM...
#     Fetching comments for video tKm0eTQ8iDw...
#     Fetching comments for video BSgG3g7ca-g...
#     Fetching comments for video E2uMn-tuETY...
#     Fetching comments for video WNCOSPaOst8...
#   Channel: UCMec1m9iUC3agiEK-nsndSg
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyDgIdNGeCLHb_y9cBGozUw7i_B...
#     Found 20 videos for channel UCMec1m9iUC3agiEK-nsndSg in July 2021.
# ...
#     Found 12 videos for channel UCe3qdG0A_gr-sEdat5y2twQ in November 2023.
#     Fetching comments for video 78BQqip-Wsw...
#     Fetching comments for video DpGbxAarm44...
#     Fetching comments for video XqwkCAvrFj4...
#     Fetching comments for video SJ3n7qm5XD4...
#     Fetching comments for video LBQpUJXsgJs...
#     Fetching comments for video 5U-yOWVebp8...
#     Fetching comments for video R1fEzzokT7M...
#     Fetching comments for video JIKI7SLDd4Q...
#     Fetching comments for video 3A40WxtpdNI...
#     Fetching comments for video NdIktoajieM...
#     Fetching comments for video RMsk0kqqGS8...
#     Fetching comments for video d1m7EfNZYi0...
#   Channel: UCwAdQUuPT6laN-AQR17fe1g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyAkacu_GSHP7YwvfcELn9JZtIe...
#     Found 10 videos for channel UCwAdQUuPT6laN-AQR17fe1g in November 2023.
#     Fetching comments for video RSxeWf-NFEQ...
#     Fetching comments for video wddZAV8_yNE...
#     Fetching comments for video 80x65RRX614...
#     Fetching comments for video O23vSwiF5Ic...
#     Fetching comments for video jy7dT1cI5FE...
#     Fetching comments for video gyeSvWiIPGo...
#     Fetching comments for video ftnTtH4RlNA...
#     Fetching comments for video aaW4B3QoqwA...
#     Fetching comments for video rfnWsey7oHQ...
#     Fetching comments for video INqK9GapzHA...
#   Channel: UCsNxHPbaCWL1tKw2hxGQD6g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyAkacu_GSHP7YwvfcELn9JZtIe...
#     Found 1 videos for channel UCsNxHPbaCWL1tKw2hxGQD6g in November 2023.
#     Fetching comments for video SBC0Ktw8JYY...
#   Channel: UCw5TLrz3qADabwezTEcOmgQ
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyAkacu_GSHP7YwvfcELn9JZtIe...
#     Found 20 videos for channel UCw5TLrz3qADabwezTEcOmgQ in November 2023.
#     Fetching comments for video wp2J87MJ-Zw...
#     Fetching comments for video ypJZQLvLAyA...
#     Fetching comments for video XsKAru6KH7g...
#     Fetching comments for video nhAQIF3ZYj4...
#     Fetching comments for video qop0XzzZli0...
#     Fetching comments for video ENNisyDwpBQ...
#     Fetching comments for video KMzWvA0GW3A...
#     Fetching comments for video lTX8zzyADM8...
#     Fetching comments for video 35DrR-gAJI8...
#     Fetching comments for video lgCTgCCtaXk...
#     Fetching comments for video zqb3QhmE91U...
#     Fetching comments for video ZZpjz5kf1sQ...
#     Fetching comments for video _IF91xIIYpg...
#     Fetching comments for video YZP_YZy7p4M...
#     Fetching comments for video 7Wzk_APogzQ...
#     Fetching comments for video GamqF6NaTAg...
#     Fetching comments for video z5lNCo-s9Yo...
#     Fetching comments for video OGCZEtzXmp0...
#     Fetching comments for video gjAYTRDa0GE...
#     Fetching comments for video pwdtiAJg5Tw...
#   Channel: UCPohbSYq4IXhv0yxiy-sT4g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyAkacu_GSHP7YwvfcELn9JZtIe...
#     Found 20 videos for channel UCPohbSYq4IXhv0yxiy-sT4g in November 2023.
#     Fetching comments for video 1OsGCHj0klA...
#     Fetching comments for video W8fpGMF6WEs...
#     Fetching comments for video bBYxpXI_V54...
#     Fetching comments for video UaPDgLn_GFw...
#     Fetching comments for video K6L8MudYrUg...
#     Fetching comments for video SZpTuXJ5rnk...
#     Fetching comments for video j6muAJdOCjU...
#     Fetching comments for video sT3xap7AjvU...
#     Fetching comments for video 7kr_ltDc12E...
#     Fetching comments for video tHgxkXBfijo...
#     Fetching comments for video BYtfoTv09pE...
#     Fetching comments for video rWf2YKWE_ug...
#     Fetching comments for video ARqF2vAI3bk...
#     Fetching comments for video xEnfuLJCZzM...
#     Fetching comments for video C7uvYizH18s...
#     Fetching comments for video PdPB99KZZpA...
#     Fetching comments for video 2cUsHEgUkNQ...
#     Fetching comments for video pa8SXqkLMUQ...
#     Fetching comments for video IVGmj19Fb9E...
#     Fetching comments for video jYi-t5W5bQk...
#   Channel: UCqW8jxh4tH1Z1sWPbkGWL4g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyAkacu_GSHP7YwvfcELn9JZtIe...
#     Found 10 videos for channel UCqW8jxh4tH1Z1sWPbkGWL4g in November 2023.
#     Fetching comments for video HE49-Jy90QA...
#     Fetching comments for video HtvDIs8zA1c...
#     Fetching comments for video 9UIyj5cIe_s...
#     Fetching comments for video 1UzimPTkQkc...
#     Fetching comments for video npLtzZd0SRM...
#     Fetching comments for video uogqBPR9pz4...
#     Fetching comments for video 8mkAs7k666Q...
#     Fetching comments for video l1YASL1BE9g...
#     Fetching comments for video BPyWC4w6Gyc...
#     Fetching comments for video OYI9CeIpp-8...
#   Channel: UCMec1m9iUC3agiEK-nsndSg
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyAkacu_GSHP7YwvfcELn9JZtIe...
#     Found 20 videos for channel UCMec1m9iUC3agiEK-nsndSg in November 2023.
#     Fetching comments for video s29WgUW0K9o...
#     Fetching comments for video f9zPq-H6aLw...
#     Fetching comments for video e5Rf_mz0_Cg...
#     Fetching comments for video PnzvnZCW-sg...
#     Fetching comments for video BpHZvOS5kZw...
#     Fetching comments for video D6phuECtpt8...
#     Fetching comments for video Tixd_GPUIr0...
#     Fetching comments for video q_vGyFLDXG4...
#     Fetching comments for video glHZ7yrice4...
#     Fetching comments for video WKGZh_ncbFc...
#     Fetching comments for video AxnG-JGiye8...
#     Fetching comments for video wzEdUK62mFo...
#     Fetching comments for video CRf_y_PefyQ...
#     Fetching comments for video Tk337jGyxyY...
#     Fetching comments for video i5NrQr3Emuw...
#     Fetching comments for video 9_PUENBYCLI...
#     Fetching comments for video 4GcK3NnWkF0...
#     Fetching comments for video JHEYsHsXHaw...
#     Fetching comments for video 0guQXelldjY...
#     Fetching comments for video yopeTjaOm58...
#   Channel: UCB7GnQlJPIL6rBBqEoX87vA
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyAkacu_GSHP7YwvfcELn9JZtIe...
#     Found 8 videos for channel UCB7GnQlJPIL6rBBqEoX87vA in November 2023.
#     Fetching comments for video YAkOaHgSIxs...
#     Fetching comments for video pIrNpcXWI8k...
#     Fetching comments for video VyT7-4eHuv8...
#     Fetching comments for video XusmWHoHwPg...
#     Fetching comments for video ue5wdjJsJ5g...
#     Fetching comments for video 8GJ7rl3wm78...
#     Fetching comments for video VhDzBxT46jU...
#     Fetching comments for video Zw7kied4yrU...
#   Channel: UCICbCSJXQauULR7K8j6e0kg
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyAkacu_GSHP7YwvfcELn9JZtIe...
#     Found 0 videos for channel UCICbCSJXQauULR7K8j6e0kg in November 2023.
#     No videos found for UCICbCSJXQauULR7K8j6e0kg in November 2023.
#   Channel: UCS2NdYUmv_PUyyKeDAo5zYA
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyAkacu_GSHP7YwvfcELn9JZtIe...
#     Found 20 videos for channel UCS2NdYUmv_PUyyKeDAo5zYA in November 2023.
#     Fetching comments for video cORvZG_S5Tg...
#     Fetching comments for video 2RUAI4mX7QE...
#     Fetching comments for video S7HIohI44c0...
#     Fetching comments for video NjEBk6CMmro...
#     Fetching comments for video DAEr0FiJnxY...
#     Fetching comments for video PM5HyEk1RG8...
#     Fetching comments for video 4v11Dd0tZDA...
#     Fetching comments for video ngYlU2dDXok...
#     Fetching comments for video 8a-mnASQ1y4...
#     Fetching comments for video 954LKAW5x70...
#     Fetching comments for video thqKKECgoq4...
#     Fetching comments for video _n4toXLxfU8...
#     Fetching comments for video g44qeXl-NSI...
#     Fetching comments for video 10h-NMRHySg...
#     Fetching comments for video KryyZsg9x9o...
#     Fetching comments for video tzfoPhNHQ98...
#     Fetching comments for video FrjLbEQPecc...
#     Fetching comments for video KrafFyZjl5w...
#     Fetching comments for video T-clhMMI8hg...
#     Fetching comments for video O-V63453Woo...
#
# --- Processing December 2023 ---
#   Channel: UCe3qdG0A_gr-sEdat5y2twQ
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyAkacu_GSHP7YwvfcELn9JZtIe...
#     Found 15 videos for channel UCe3qdG0A_gr-sEdat5y2twQ in December 2023.
#     Fetching comments for video zimUiDNcBEw...
#     Fetching comments for video wF2t2KavoYw...
#     Fetching comments for video 07MEzcGTQ5A...
#     Fetching comments for video UipVTo-FVhM...
#     Fetching comments for video oWPz5vGkGJg...
#     Fetching comments for video kmHIRIbE3V0...
#     Fetching comments for video b1FAtMo0Uqo...
#     Fetching comments for video 2zSIt7DgOe4...
#     Fetching comments for video apmzDLCTvVQ...
#     Fetching comments for video SmfOta0Hj-4...
#     Fetching comments for video qKH2Tgyeq3Q...
#     Fetching comments for video 23SUFi5Y_iE...
#     Fetching comments for video XFdweYMN6-A...
#     Fetching comments for video gWvoznlJ2-I...
#     Fetching comments for video QU0LRBZGjg0...
#   Channel: UCwAdQUuPT6laN-AQR17fe1g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyAkacu_GSHP7YwvfcELn9JZtIe...
#     Found 6 videos for channel UCwAdQUuPT6laN-AQR17fe1g in December 2023.
#     Fetching comments for video azdzSz2iwjU...
#     Fetching comments for video dPdufQ51i2U...
#     Fetching comments for video x3FY9f8S8Y0...
#     Fetching comments for video gag7tfqZg6U...
#     Fetching comments for video MPhMTh4eulE...
#     Fetching comments for video BZVcibbRqNo...
#   Channel: UCsNxHPbaCWL1tKw2hxGQD6g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyAkacu_GSHP7YwvfcELn9JZtIe...
#     Found 4 videos for channel UCsNxHPbaCWL1tKw2hxGQD6g in December 2023.
#     Fetching comments for video 13dbtpqYWJc...
#     Fetching comments for video rgfwv04ZF_U...
#     Fetching comments for video oGNiSQ6hn08...
#     Fetching comments for video -_d86XHozFo...
#   Channel: UCw5TLrz3qADabwezTEcOmgQ
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyAkacu_GSHP7YwvfcELn9JZtIe...
#     Found 20 videos for channel UCw5TLrz3qADabwezTEcOmgQ in December 2023.
#     Fetching comments for video txgkTH3ZElY...
#     Fetching comments for video 6qZXFeIzGfo...
#     Fetching comments for video DE74syVyaq8...
#     Fetching comments for video ULYzVAh3l3k...
#     Fetching comments for video Nf_aw99f0sI...
#     Fetching comments for video shAetgz3Phw...
#     Fetching comments for video YN-Nxx_mHZA...
#     Fetching comments for video 0COsj1U5bFk...
#     Fetching comments for video _h0W-Vj4QM0...
#     Fetching comments for video ouT8Mi_BohI...
#     Fetching comments for video hpT6HfTyuNc...
#     Fetching comments for video 959BHNuMRA8...
#     Fetching comments for video _m2Sn-3csP8...
#     Fetching comments for video VrzFTkx9L_4...
#     Fetching comments for video jw2LTJYrSYk...
#     Fetching comments for video 5hmdI-bf6I4...
#     Fetching comments for video yRw6dxpsyZU...
#     Fetching comments for video AQzvvFvx2DI...
#     Fetching comments for video igAtDe_oYvk...
#     Fetching comments for video EmX3s6ILIaQ...
#   Channel: UCPohbSYq4IXhv0yxiy-sT4g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyAkacu_GSHP7YwvfcELn9JZtIe...
#     Found 20 videos for channel UCPohbSYq4IXhv0yxiy-sT4g in December 2023.
#     Fetching comments for video vFX5LmZJu2w...
#     Fetching comments for video SHn3zK_HmJU...
#     Fetching comments for video GC134MX30zo...
#     Fetching comments for video bKM8c7ruQfc...
#     Fetching comments for video HmPGvO-6IV4...
#     Fetching comments for video ERrKRVJf-GM...
#     Fetching comments for video ikm1h61DwAo...
#     Fetching comments for video D2xCRqR_bJA...
#     Fetching comments for video NhrZr2f-9EM...
#     Fetching comments for video _wf7A0EQQ5M...
#     Fetching comments for video QVh2rbQ2hdU...
#     Fetching comments for video 77ovXFwiCCE...
#     Fetching comments for video dP4HE8z4IIM...
#     Fetching comments for video kITc_-OHIhQ...
#     Fetching comments for video rctbPIj2jp0...
#     Fetching comments for video XnbDrznqn7s...
#     Fetching comments for video PL0ZE-oSEqk...
#     Fetching comments for video 2b3SBwVfZ4w...
#     Fetching comments for video OUipxyGNmKw...
#     Fetching comments for video oU9A9BUjWQ8...
#   Channel: UCqW8jxh4tH1Z1sWPbkGWL4g
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyAkacu_GSHP7YwvfcELn9JZtIe...
#     Found 10 videos for channel UCqW8jxh4tH1Z1sWPbkGWL4g in December 2023.
#     Fetching comments for video XKacSra5H6U...
#     Fetching comments for video Nyt5qcYJlIM...
#     Fetching comments for video F9CQecczpVs...
#     Fetching comments for video Nn8vIjrdDiQ...
#     Fetching comments for video sxbomSD30pU...
#     Fetching comments for video UGpqSP2P6Vw...
#     Fetching comments for video BmX8XlncX04...
#     Fetching comments for video WgESz9JwmcY...
#     Fetching comments for video FQhzfzTd2Kw...
#     Fetching comments for video jk7FL1BQ-Vo...
#   Channel: UCMec1m9iUC3agiEK-nsndSg
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyAkacu_GSHP7YwvfcELn9JZtIe...
#     Found 20 videos for channel UCMec1m9iUC3agiEK-nsndSg in December 2023.
#     Fetching comments for video CTf9gaPggs4...
#     Fetching comments for video iBO1mST7Jc8...
#     Fetching comments for video SpeZVK8F0K0...
#     Fetching comments for video FTbzONQDZck...
#     Fetching comments for video oj7BBb0ImEs...
#     Fetching comments for video dZvfCkt0e5Y...
#     Fetching comments for video Q0g_znBtzVM...
#     Fetching comments for video ZzukSNLOF9c...
#     Fetching comments for video UpCloZFXtjI...
#     Fetching comments for video bZVcbVlKqvE...
#     Fetching comments for video ueGV8HmdVqk...
#     Fetching comments for video dIfD_77nlxU...
#     Fetching comments for video QY5BMezLbWs...
#     Fetching comments for video DiWIMKQi6W4...
#     Fetching comments for video Gks-_No9WQQ...
#     Fetching comments for video IglQbysi1aU...
#     Fetching comments for video bTYnhlD17RU...
#     Fetching comments for video w6nVKXVYnNc...
#     Fetching comments for video N63OGOBdeSM...
#     Fetching comments for video 8ZVjwno87Xw...
#   Channel: UCB7GnQlJPIL6rBBqEoX87vA
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyAkacu_GSHP7YwvfcELn9JZtIe...
#     Found 10 videos for channel UCB7GnQlJPIL6rBBqEoX87vA in December 2023.
#     Fetching comments for video lfArzlEXu1o...
#     Fetching comments for video 02pJp0SSOm8...
#     Fetching comments for video 6yH1A3jOkYQ...
#     Fetching comments for video 3reNGUatnUE...
#     Fetching comments for video YKMfXqnAag4...
#     Fetching comments for video 1_R1CrHnSqs...
#     Fetching comments for video CuFCctfYx8E...
#     Fetching comments for video pvQ9BwfVHbE...
#     Fetching comments for video UDODranm_8E...
#     Fetching comments for video eSU6bwD2KOg...
#   Channel: UCICbCSJXQauULR7K8j6e0kg
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyAkacu_GSHP7YwvfcELn9JZtIe...
#     Found 0 videos for channel UCICbCSJXQauULR7K8j6e0kg in December 2023.
#     No videos found for UCICbCSJXQauULR7K8j6e0kg in December 2023.
#   Channel: UCS2NdYUmv_PUyyKeDAo5zYA
#     Fetching videos: https://www.googleapis.com/youtube/v3/search?key=AIzaSyAkacu_GSHP7YwvfcELn9JZtIe...
#     Found 20 videos for channel UCS2NdYUmv_PUyyKeDAo5zYA in December 2023.
#     Fetching comments for video jtPKOCzl_sM...
#     Fetching comments for video Bfx05a0qECU...
#     Fetching comments for video 4NBqSNx3hLk...
#     Fetching comments for video T0LA0vkaV_E...
#     Fetching comments for video CPTVDbgNvOI...
#     Fetching comments for video CfwHMwTk2oM...
#     Fetching comments for video sngvYqn7Tc8...
#     Fetching comments for video FkF7ZoPQXuw...
#     Fetching comments for video J_6rR-CqR3c...
#     Fetching comments for video 48Pd2RyNFbM...
#     Fetching comments for video Hvcect78gpc...
#     Fetching comments for video AP86_ldUVjI...
#     Fetching comments for video E0sczpJXsCQ...
#     Fetching comments for video 3sMMQcNjEWg...
#     Fetching comments for video JMpFoGHQ1Y8...
#     Fetching comments for video poy-DSq4Heg...
#     Fetching comments for video C5O68p5U4tw...
#     Fetching comments for video u5k2sDK0Te4...
#     Fetching comments for video BK4icehwJZ4...
#     Fetching comments for video DB0hv6bqwwo...
#
# Saved monthly sentiment data to 'youtube_monthly_sentiment.csv'
# Script finished.
